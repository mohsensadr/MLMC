# %%
# !cargo run
# Out:
#    Compiling MLMC v0.1.0 (/Users/mohsensadr/Codes/GitHub/MLMC)
#     Finished `dev` profile [unoptimized + debuginfo] target(s) in 0.22s
#      Running `/Users/mohsensadr/Codes/GitHub/MLMC/target/debug/MLMC`
# -----------------
#
# Running MLMC for eps = 0.01
#
# P: 1.0959028300588671
# Nl: [
#     3477.0,
#     100.0,
#     100.0,
#     9.0,
# ]
# alpha: 0.6281939785639636
# beta: 2.4706758997229192
# gamma: 1.0
# -----------------
#
# Running MLMC for eps = 0.001
#
# P: 1.0853814352920765
# Nl: [
#     304219.0,
#     7521.0,
#     3712.0,
#     908.0,
#     315.0,
# ]
# alpha: 1.0373334878046874
# beta: 2.058570060948553
# gamma: 1.0
# -----------------
#
# Running MLMC for eps = 0.0001
#
# P: 1.0858115667590094
# Nl: [
#     30671069.0,
#     766944.0,
#     367880.0,
#     90969.0,
#     31636.0,
#     11185.0,
#     3900.0,
#     1394.0,
# ]
# alpha: 1.0225756822881025
# beta: 2.0355777433428557
# gamma: 1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("mlmc_vs_mc.csv")

plt.figure(figsize=(3, 3))
plt.loglog(df["eps"], df["mlmc_cost"], "o-", label="MLMC")
plt.loglog(df["eps"], df["mc_cost"], "s-", label="MC")
plt.xlabel("ε")
plt.ylabel("Cost")
plt.legend()
plt.grid(True, which="both")
plt.savefig('mlmc_vs_mc_cost.png', bbox_inches='tight')

plt.figure(figsize=(3, 3))
df = pd.read_csv("mlmc_details.csv")
eps = df["eps"]
L = df["L"]
Nl = df["Nl"]
for i in range(L.shape[0]):
    # convert string list to integers
    nl_values = list(map(int, Nl[i].split()))
    plt.plot(range(len(nl_values)), nl_values, marker="o", label=f"ε={eps[i]}")
plt.xlabel(r"no. levels")
plt.legend()
plt.yscale("log")
plt.ylabel("no. of samples per level")
plt.grid(True)
plt.savefig('mlmc_Nl_eps.png', bbox_inches='tight')
plt.show()
